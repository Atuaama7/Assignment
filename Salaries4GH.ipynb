# %%
import pandas as pd
import numpy as np

# %%
#define variables for the csv files, this step is not mandatory 
#but it will help to understand the importing data step in Python
df_salaries = pd.read_csv("C:/Users/91836/Downloads/Salaries.csv")

# %%
df_salaries.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df_salaries.shape
# Out:
# (78, 6)

# %%
df_salaries["Benchmarks"] = 70000

# %%
df_salaries.head()
# Out:
#    rank discipline  phd  service   sex  salary  Benchmarks
# 0  Prof          B   56       49  Male  186960       70000
# 1  Prof          A   12        6  Male   93000       70000
# 2  Prof          A   23       20  Male  110515       70000
# 3  Prof          A   40       31  Male  131205       70000
# 4  Prof          B   20       18  Male  104800       70000

# %%
# CALCULATE A COLUMN
df_salaries["Salary_score"] = round(df_salaries["salary"] / df_salaries["Benchmarks"],2)
df_salaries.head()
# Out:
#    rank discipline  phd  service   sex  salary  Benchmarks  Salary_score
# 0  Prof          B   56       49  Male  186960       70000          2.67
# 1  Prof          A   12        6  Male   93000       70000          1.33
# 2  Prof          A   23       20  Male  110515       70000          1.58
# 3  Prof          A   40       31  Male  131205       70000          1.87
# 4  Prof          B   20       18  Male  104800       70000          1.50

# %%
# DROPPING a COLUMN
# Method 1: Subset the dataframe by including only spescific columns.
Subset_df_salaries=df_salaries.drop(['rank','discipline','service'],axis=1)
Subset_df_salaries.head()
# Out:
#    phd   sex  salary  Benchmarks  Salary_score
# 0   56  Male  186960       70000          2.67
# 1   12  Male   93000       70000          1.33
# 2   23  Male  110515       70000          1.58
# 3   40  Male  131205       70000          1.87
# 4   20  Male  104800       70000          1.50

# %%
# Method 2: Use the drop method to drop the salary column.
Subset_df_salaries=df_salaries.drop(['sex','salary'], axis=1)
Subset_df_salaries.head()
#Subset_raw_df
# Out:
#    rank discipline  phd  service  Benchmarks  Salary_score
# 0  Prof          B   56       49       70000          2.67
# 1  Prof          A   12        6       70000          1.33
# 2  Prof          A   23       20       70000          1.58
# 3  Prof          A   40       31       70000          1.87
# 4  Prof          B   20       18       70000          1.50

# %%
#Concatenate a dataframe and Append
# Append data to a dataframe
#Create a list
append_to_df1 = []

append_to_df1.append(
  ["123", "Syed", "36"]
  )

df1 = pd.DataFrame(append_to_df1, columns=["ID", "Name", "Age"])

df1.head()
# Out:
#     ID  Name Age
# 0  123  Syed  36

# %%
import pandas as pd 
mylist=[1,2,3,4]
dflist=pd.DataFrame(mylist,columns=['var1'])
dflist.head()
# Out:
#    var1
# 0     1
# 1     2
# 2     3
# 3     4

# %%
# Append data to a dataframe
#Create a list
append_to_df2 = []

append_to_df2.append(
  ["345", "Ali", "19"]
  )

df2 = pd.DataFrame(append_to_df2, columns=["ID", "Name", "Age"])

df2.head()
# Out:
#     ID Name Age
# 0  345  Ali  19

# %%
combined_df = pd.concat([df1, df2], ignore_index=True, sort=False)
combined_df
# Out:
#     ID  Name Age
# 0  123  Syed  36
# 1  345   Ali  19

# %%
df_Salaries = pd.read_csv("C:/Users/91836/Downloads/Salaries.csv")

# %%
df1=df_Salaries.groupby(['rank','sex'], sort = True)
df1.head()
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 6   AssocProf          A   20       17    Male   81285
# 12   AsstProf          B    1        0    Male   88000
# 16   AsstProf          B    8        3    Male   75044
# 17   AsstProf          B    4        0    Male   92000
# 20   AsstProf          B    4        4    Male   92000
# 22   AsstProf          A    4        2    Male   73000
# 30  AssocProf          B    9        7    Male  107008
# 34  AssocProf          B   12        8    Male  119800
# 39       Prof          B   18       18  Female  129000
# 40       Prof          A   39       36  Female  137000
# 41  AssocProf          A   13        8  Female   74830
# ...

# %%
df2=df_Salaries.groupby(['sex'], sort = True)['rank'].count()

df2
# Out:
# sex
# Female    39
# Male      39
# Name: rank, dtype: int64

# %%
df2=df_Salaries.groupby(['rank'], sort = True)['rank'].count()

df2
# Out:
# rank
# AssocProf    13
# AsstProf     19
# Prof         46
# Name: rank, dtype: int64
